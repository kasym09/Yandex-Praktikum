# %% [markdown]
# <font color='blue' size=5><b>Комментарий ревьюера</b></font>
#
# <font color='blue'>Привет! Меня зовут Павел Григорьев, и я буду проверять этот проект.<br>Моя основная цель - не указать на совершённые тобой ошибки, а поделиться своим опытом и помочь тебе совершенствоваться как профессионалу.<br>Спасибо за проделанную работу! Предлагаю общаться на «ты».</font>
# <details>
# 	<summary><u>Инструкция по организационным моментам (кликабельно)</u></summary>
# <font color='blue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font>
#
#
# ---
#
#
# <font color='blue'>синий текст - просто текст комментария</font>
#
# <font color='green'>✔️ и зеленый текст - все отлично</font>
#
# <font color='orange'>⚠️ и оранжевый текст - сделано все правильно, однако есть рекомендации, на что стоит обратить внимание</font>
#
# <font color='red'>❌ и красный текст - есть недочеты</font>
#
#
# </details>
#     </br>
# <font color='blue'>Пожалуйста, не удаляй мои комментарии в случае возврата работы, так будет проще разобраться, какие были недочеты, а также сразу увидеть исправленное. </font>
#
# Ответы на мои комментарии лучше тоже помечать.
# Например: <font color='purple'><b>Комментарий студента</b></font>
#
# <font color='blue'><b>Давай смотреть, что получилось!</b></font>

# %% [markdown]
# <font color='blue' size=3><b>Комментарий ревьюера 2</b></font>
#
# <font color='blue'>Привет еще раз. Спасибо, за исправления. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.</font>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Загружаем библиотеки

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from plotly import graph_objects as go

from sklearn.model_selection import train_test_split
from sklearn.pipeline import  make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.dummy import DummyRegressor

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Хорошее оформление импортов! \
# Импорты собраны в одной ячейке, разделены на функциональные группы пустой строкой.</font>

# %% [markdown]
# ##### Загрузим данные

# %%
try:
    full = pd.read_csv('D:\DDownloads/gold_industry_full.csv',
                       index_col='date') 
    train = pd.read_csv('D:\DDownloads/gold_industry_train.csv',
                        index_col='date')
    test = pd.read_csv('D:\DDownloads/gold_industry_test.csv',
                       index_col='date') 
except:
    full = pd.read_csv('/datasets/gold_recovery_full_new.csv', index_col='date')
    train = pd.read_csv('/datasets/gold_recovery_train_new.csv', index_col='date') 
    test = pd.read_csv('/datasets/gold_recovery_test_new.csv', index_col='date')

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Классно, что сразу объявляешь 'date' индексом.</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Закомментированный код лучше удалять из проекта.</font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font>  сделано)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>👍</font>

# %% [markdown]
# #### 1.1 Откроем файлы и изучим их

# %%
#смотрю описание таблиц:
for dataset in [full, train, test]:
    display(dataset.head(5))
    print()
    dataset.info()
    print('Кол-во дубликатов =', dataset.duplicated().sum())
    print()
    display(dataset.describe())
    print('---------------------------------------------------')
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Данные загружены корректно, первичный осмотр проведен.</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Метод info() не нуждается в print(), и возвращает None.</font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font>  удалил принт

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>👍</font>

# %% [markdown]
# #### 1.2. Проверьте, что эффективность обогащения рассчитана правильно.

# %%
#создаю функцию для расчета эффективности обогащения:
def recovery_calc(rougher_output, rougher_input, rougher_tail):
    recovery = (rougher_output * (rougher_input - rougher_tail)) \
    / (rougher_input * (rougher_output - rougher_tail)) * 100
    return recovery

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Расчёт верный!</font>

# %%
#вычисляю эффективность обогащения на обучающей выборке для признака rougher.output.recovery:
recovery = recovery_calc(train['rougher.output.concentrate_au'],
                         train['rougher.input.feed_au'],
                         train['rougher.output.tail_au'])
recovery
# Out:
# date
# 2016-01-15 00:00:00    87.107763
# 2016-01-15 01:00:00    86.843261
# 2016-01-15 02:00:00    86.842308
# 2016-01-15 03:00:00    87.226430
# 2016-01-15 04:00:00    86.688794
#                          ...
# 2018-08-18 06:59:59    89.574376
# 2018-08-18 07:59:59    87.724007
# 2018-08-18 08:59:59    88.890579
# 2018-08-18 09:59:59    89.858126
# 2018-08-18 10:59:59    89.514960
# Length: 14149, dtype: float64

# %%
#нахожу MAE между расчётами и значением признака rougher.output.recovery:
mae = mean_absolute_error(train['rougher.output.recovery'], recovery)
print('MAE между расчётами и значением признака rougher.output.recovery =', mae)
# Out:
# MAE между расчётами и значением признака rougher.output.recovery = 9.73512347450521e-15

# %% [markdown]
# ##### Вывод
# Учитывая очень малую среднюю абсолютную ошибку (9.83 × 10 в степени -15) между расчетами и значениями признака rougher.output.recovery, можно сделать вывод о правильности расчета эффективности обогащения на обучающей выборке.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>👍</font>

# %% [markdown]
# #### 1.3. Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
#выделяю признаки, которых нет в выборке test:
missed_attributes = set(train.columns) - set(test.columns)

#смотрю, к какому типу относятся признаки, которых нет в выборке test:
train[missed_attributes].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 34 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   primary_cleaner.output.tail_pb                      14134 non-null  float64
#  1   rougher.calculation.sulfate_to_au_concentrate       14148 non-null  float64
#  2   primary_cleaner.output.tail_ag                      14148 non-null  float64
#  3   secondary_cleaner.output.tail_au                    14149 non-null  float64
#  4   primary_cleaner.output.concentrate_pb               14063 non-null  float64
#  5   rougher.output.tail_sol                             14149 non-null  float64
#  6   rougher.output.tail_pb                              14149 non-null  float64
#  7   rougher.calculation.au_pb_ratio                     14149 non-null  float64
# ...

# %% [markdown]
# ##### Вывод:
# - Все признаки, отсутствующие в тестовой выборке test, имеют тип float
# - В выборке test отсутствует 34 признака, из которых 30 относятся к типу output (параметры продукта), а 4 относятся к типу calculation (расчётные характеристики)
# - Для дальнейшего анализа и построения модели необходимо добавить в тестовую выборку целевые признаки из полной выборки full. Также на этапе обучения модели следует удалить из обучающей выборки train признаки, которые отсутствуют в тестовой выборке test

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Верно!</font>

# %% [markdown]
# ##### 1.4. Проведите предобработку данных

# %%
#смотрю кол-во пропусков в таблицах:
for dataset in [full, train, test]:
    print(dataset.isna().sum()[dataset.isna().sum()!=0].sort_values(ascending=False))
    print('----------------')
# Out:
# secondary_cleaner.output.tail_sol             1748
# rougher.input.floatbank11_xanthate             453
# rougher.state.floatbank10_e_air                436
# primary_cleaner.output.concentrate_sol         370
# secondary_cleaner.state.floatbank2_a_air       220
#                                               ...
# primary_cleaner.state.floatbank8_c_level         1
# primary_cleaner.state.floatbank8_b_level         1
# primary_cleaner.state.floatbank8_a_level         1
# final.output.tail_ag                             1
# secondary_cleaner.state.floatbank6_a_level       1
# Length: 63, dtype: int64
# ----------------
# secondary_cleaner.output.tail_sol             1605
# rougher.state.floatbank10_e_air                436
# rougher.input.floatbank11_xanthate             428
# primary_cleaner.output.concentrate_sol         286
# secondary_cleaner.state.floatbank2_a_air       217
#                                               ...
# rougher.state.floatbank10_a_air                  1
# ...

# %% [markdown]
# включим целевые признаки из полного набора данных full в тестовую выборку test на основе совпадения дат.

# %%
test = test.merge(full[['final.output.recovery', 'rougher.output.recovery']], on='date', how='left')
test.shape
# Out:
# (5290, 54)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> Верно, при объединении таблиц нужно привязаться ко времени наблюдения.</font>

# %% [markdown]
# заполним оставшиеся пропуски соседними:

# %%
#заполняю следующим непропущенным значением
train = train.fillna(method='ffill')
test = test.fillna(method='ffill')

train.isna().values.any(), test.isna().values.any()
# Out:
# (False, False)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'>Лучше использовать `ffill`, при работе пропуски заполнят предыдущимм значением, а не будущим.</font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font>  сделано)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>👍</font>

# %% [markdown]
# ##### Вывод
# ходе выполнения этапа 1.4. мы успешно обработали пропуски в тренировочной и тестовой выборках, а также добавили необходимые признаки в тестовую выборку. Более того, мы подтвердили правильность расчета эффективности обогащения в тренировочной выборке.
#
# Это означает, что на данном этапе мы смогли предобработать данные, обеспечить их полноту и согласованность, а также подтвердить корректность вычислений. Это важный шаг в подготовке данных для последующего построения модели.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️ <br>
# <font color='green'>Здорово, что не забываешь про промежуточные выводы.</font>

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# #### 2.1. Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах:

# %%
#извлекем признаки rougher.input.feed_ag, rougher.output.concentrate_ag, 
#primary_cleaner.output.concentrate_ag и final.output.concentrate_ag
concentrate_ag = full[['rougher.input.feed_ag',
                       'rougher.output.concentrate_ag',
                       'primary_cleaner.output.concentrate_ag',
                       'final.output.concentrate_ag'
                      ]].mean(axis=0)
concentrate_ag
# Out:
# rougher.input.feed_ag                     8.794927
# rougher.output.concentrate_ag            11.994759
# primary_cleaner.output.concentrate_ag     8.442408
# final.output.concentrate_ag               5.168470
# dtype: float64

# %%
#для свинца:
concentrate_pb = full[['rougher.input.feed_pb',
                       'rougher.output.concentrate_pb',
                      'primary_cleaner.output.concentrate_pb',
                       'final.output.concentrate_pb'
                      ]].mean(axis=0)
concentrate_pb
# Out:
# rougher.input.feed_pb                    3.598085
# rougher.output.concentrate_pb            7.606272
# primary_cleaner.output.concentrate_pb    9.829530
# final.output.concentrate_pb              9.978895
# dtype: float64

# %%
#для золота:
concentrate_au = full[['rougher.input.feed_au',
                       'rougher.output.concentrate_au',
                      'primary_cleaner.output.concentrate_au',
                       'final.output.concentrate_au'
                      ]].mean(axis=0)
concentrate_au
# Out:
# rougher.input.feed_au                     8.266097
# rougher.output.concentrate_au            19.772000
# primary_cleaner.output.concentrate_au    32.119400
# final.output.concentrate_au              44.076513
# dtype: float64

# %%
# #линейный график:
# concentrate_ag.plot(style='-o', grid=True, figsize=(12,4), label='Ag') 

# concentrate_pb.plot(style='-o', grid=True, figsize=(12,4), label='Pb')

# concentrate_au.plot(style='-o', grid=True, figsize=(12,4), label='Au')

# plt.title('Изменения концентраций Ag, Pb, Au на этапах очистки')
# plt.legend()
# plt.show()

# %%
# График распределения концентрации Ag
plt.figure(figsize=(12, 4))
plt.hist(full['rougher.input.feed_ag'], bins=50, alpha=0.5, label='rougher.input.feed_ag')
plt.hist(full['rougher.output.concentrate_ag'], bins=50, alpha=0.5, label='rougher.output.concentrate_ag')
plt.hist(full['primary_cleaner.output.concentrate_ag'], bins=50, alpha=0.5, label='primary_cleaner.output.concentrate_ag')
plt.hist(full['final.output.concentrate_ag'], bins=50, alpha=0.5, label='final.output.concentrate_ag')
plt.xlabel('Концентрация Ag')
plt.ylabel('Количество наблюдений')
plt.title('Распределение концентрации Ag на различных этапах очистки')
plt.legend()
plt.grid(True)
plt.show()

# Повторите те же шаги для графиков распределения Pb
plt.figure(figsize=(12, 4))
plt.hist(full['rougher.input.feed_pb'], bins=50, alpha=0.5, label='rougher.input.feed_pb')
plt.hist(full['rougher.output.concentrate_pb'], bins=50, alpha=0.5, label='rougher.output.concentrate_pb')
plt.hist(full['primary_cleaner.output.concentrate_pb'], bins=50, alpha=0.5, label='primary_cleaner.output.concentrate_pb')
plt.hist(full['final.output.concentrate_pb'], bins=50, alpha=0.5, label='final.output.concentrate_pb')
plt.xlabel('Концентрация Pb')
plt.ylabel('Количество наблюдений')
plt.title('Распределение концентрации Pb на различных этапах очистки')
plt.legend()
plt.grid(True)

# Повторите те же шаги для графиков распределения Au
plt.figure(figsize=(12, 4))
plt.hist(full['rougher.input.feed_au'], bins=50, alpha=0.5, label='rougher.input.feed_au')
plt.hist(full['rougher.output.concentrate_au'], bins=50, alpha=0.5, label='rougher.output.concentrate_au')
plt.hist(full['primary_cleaner.output.concentrate_au'], bins=50, alpha=0.5, label='primary_cleaner.output.concentrate_au')
plt.hist(full['final.output.concentrate_au'], bins=50, alpha=0.5, label='final.output.concentrate_au')
plt.xlabel('Концентрация Au')
plt.ylabel('Количество наблюдений')
plt.title('Распределение концентрации Au на различных этапах очистки')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Вывод
# - концентрация золата увеличивается с каждым этапом очистки, достигая на финальном этапе значительно более высокого уровня, чем
# на начальных этапах, что хорошо.
# - свинец так же растет с каждым этапом, но незаметно
# - серебро наоборот падает, видимо большее кол-во серебра остается в отвальных хвостах.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> Нужно вывести графики **распределений** (не средних) и описать их особенности.</s></font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font>  сделано)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ⚠️\
# <font color='darkorange'> Стоит отметить нулевые значения на диаграммах.</font>

# %%
y1 = train['rougher.input.feed_size']
y2 = test['rougher.input.feed_size']

plt.hist(y1, bins=100, density=True, color='orange', label='train', range=(20, 150), alpha=0.5)
plt.hist(y2, bins=100, density=True, color='blue', label='test', range=(20, 150), alpha=0.5)
plt.rcParams['figure.figsize'] = (20, 5)
plt.legend(loc='upper left')
plt.title('Распределения размеров гранул сырья на обучающей и тестовой выборках на этапе флотации')
plt.show()

# %%
y1 = train['primary_cleaner.input.feed_size']
y2 = test['primary_cleaner.input.feed_size']

plt.hist(y1, bins=100, density=True, color='orange', label='train', range=(5, 10), alpha=0.5)
plt.hist(y2, bins=100, density=True, color='blue', label='test', range=(5, 10), alpha=0.5)
plt.rcParams['figure.figsize'] = (25, 5)
plt.legend(loc='upper left')
plt.title('Распределения размеров гранул сырья на обучающей и тестовой выборках на этапе первичной очистки')
plt.show()

# %% [markdown]
# #### Вывод
# На этапе флотации размеры гранул в обучающей выборке достигают до 55, в то время как в тестовой выборке они ограничены до 45. На этапе первичной очистки размеры гранул в обеих выборках показывают схожие распределения, ограниченные до примерно 7.4 в обучающей выборке и 7.7 в тестовой выборке. Распределение размеров гранул на этом этапе на тестовой выборке примерно однородно в диапазоне от 6.7 до 7.7.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Вывод верный!</font> \
# <font color='red'><s> В данном случае нужно использовать параметр "density=True" в методе ".hist()". Так бы нам удалось перейти от количества к доле.</s></font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font>  применил параметр density=True

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> Супер! Выборки разного размера, нужна нормализация по плотности 👍</font>

# %% [markdown]
# #### 2.3. Исследуйте суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.

# %%
#таблицa суммарных концентраций на разных стадиях: 
    
combo_concentrate = pd.DataFrame()

combo_concentrate['rougher.input'] = full['rougher.input.feed_ag'] \
+ full['rougher.input.feed_pb'] \
+ full['rougher.input.feed_sol'] \
+ full['rougher.input.feed_au']

combo_concentrate['rougher.output'] = full['rougher.output.concentrate_ag'] \
+ full['rougher.output.concentrate_pb'] \
+ full['rougher.output.concentrate_sol'] \
+ full['rougher.output.concentrate_au']

combo_concentrate['primary_cleaner.output'] = full['primary_cleaner.output.concentrate_ag'] \
+ full['primary_cleaner.output.concentrate_pb'] \
+ full['primary_cleaner.output.concentrate_sol'] \
+ full['primary_cleaner.output.concentrate_au']

combo_concentrate['final.output'] = full['final.output.concentrate_ag'] \
+ full['final.output.concentrate_pb'] \
+ full['final.output.concentrate_sol'] \
+ full['final.output.concentrate_au']

combo_concentrate.describe()
# Out:
#        rougher.input  rougher.output  primary_cleaner.output  final.output
# count   19245.000000    19416.000000            19069.000000  19227.000000
# mean       57.407926       68.188914               60.949928     68.727562
# std         7.165219       12.478522                9.953770      7.423741
# min         0.040000        0.000000                0.000000      0.000000
# 25%        53.660745       66.026048               59.165854     67.985659
# 50%        57.647093       70.186130               62.615189     69.632597
# 75%        62.012223       74.362878               65.725507     71.390461
# max        76.978947       88.140119               80.749343     80.210644

# %%
#гистограммы по стадиям:

y1 = combo_concentrate['rougher.input']
y2 = combo_concentrate['rougher.output']
y3 = combo_concentrate['primary_cleaner.output']
y4 = combo_concentrate['final.output']

plt.hist(y1, bins=150, color='orange', label='rougher.input', range=(0, 90), alpha=0.5)
plt.hist(y2, bins=150, color='blue', label='rougher.output', range=(0, 90), alpha=0.5)
plt.hist(y3, bins=150, color='grey', label='primary_cleaner.output', range=(0, 90), alpha=0.5)
plt.hist(y4, bins=150, color='green', label='final.output', range=(0, 90), alpha=0.5)

plt.rcParams['figure.figsize'] = (20, 5)
plt.legend(loc='upper left')
plt.title('Распределения суммарной концентрации всех веществ на разных стадиях')
plt.show()

# %%
fig, ax = plt.subplots(4, 1, figsize=(20, 30))

ax[0].hist(full['rougher.input.feed_ag'], bins=40)
ax[1].hist(full['rougher.output.concentrate_ag'], bins=40)
ax[2].hist(full['primary_cleaner.output.concentrate_ag'], bins=40)
ax[3].hist(full['final.output.concentrate_ag'], bins=40)

ax[0].set_xlabel('Концентрация Ag до удаления выбросов')
ax[1].set_xlabel('Концентрация Ag после флотации до удаления выбросов')
ax[2].set_xlabel('Концентрация Ag после первичной очистки до удаления выбросов')
ax[3].set_xlabel('Концентрация Ag после финального этапа до удаления выбросов')

ax[0].set_ylabel('Количество наблюдений')
ax[1].set_ylabel('Количество наблюдений')
ax[2].set_ylabel('Количество наблюдений')
ax[3].set_ylabel('Количество наблюдений')

ax[0].set_title('Гистограмма концентрации Ag до удаления выбросов')
ax[1].set_title('Гистограмма концентрации Ag после флотации до удаления выбросов')
ax[2].set_title('Гистограмма концентрации Ag после первичной очистки до удаления выбросов')
ax[3].set_title('Гистограмма концентрации Ag после финального этапа до удаления выбросов')

plt.show()

# %%
#удалим из full концентрации до 1:
full = full[(full['rougher.input.feed_ag'] >= 1) &
            (full['rougher.input.feed_pb'] >= 1) &
            (full['rougher.input.feed_sol'] >= 1) &
            (full['rougher.input.feed_au'] >= 1) &
            (full['rougher.output.concentrate_ag'] >= 1) &
            (full['rougher.output.concentrate_pb'] >= 1) &
            (full['rougher.output.concentrate_sol'] >= 1) &
            (full['rougher.output.concentrate_au'] >= 1) &
            (full['primary_cleaner.output.concentrate_ag'] >= 1) &
            (full['primary_cleaner.output.concentrate_pb'] >= 1) &
            (full['primary_cleaner.output.concentrate_sol'] >= 1) &
            (full['primary_cleaner.output.concentrate_au'] >= 1) &
            (full['final.output.concentrate_ag'] >= 1) &
            (full['final.output.concentrate_pb'] >= 1) &
            (full['final.output.concentrate_sol'] >= 1) &
            (full['final.output.concentrate_au'] >= 1)]

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Нехватка одного металла может быть пустой рудой. Достоверными выбросами можно считать нулевые значения суммарных концентрация всех веществ, что можно интерпритировать как сбой измерительного оборудования.</font>

# %%
#так же для train:
train = train[(train['rougher.input.feed_ag'] >= 1) &
            (train['rougher.input.feed_pb'] >= 1) &
            (train['rougher.input.feed_sol'] >= 1) &
            (train['rougher.input.feed_au'] >= 1) &
            (train['rougher.output.concentrate_ag'] >= 1) &
            (train['rougher.output.concentrate_pb'] >= 1) &
            (train['rougher.output.concentrate_sol'] >= 1) &
            (train['rougher.output.concentrate_au'] >= 1) &
            (train['primary_cleaner.output.concentrate_ag'] >= 1) &
            (train['primary_cleaner.output.concentrate_pb'] >= 1) &
            (train['primary_cleaner.output.concentrate_sol'] >= 1) &
            (train['primary_cleaner.output.concentrate_au'] >= 1) &
            (train['final.output.concentrate_ag'] >= 1) &
            (train['final.output.concentrate_pb'] >= 1) &
            (train['final.output.concentrate_sol'] >= 1) &
            (train['final.output.concentrate_au'] >= 1)]

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> Тестовую выборку нельзя фильтровать. Это лишает её репрезентативности.</s></font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font>  удалил строку с фильтрацией тестовой выборки

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>👍</font>

# %%
# Построение гистограммы для суммарной концентрации в данных full
plt.hist(full['rougher.input.feed_ag'] + full['rougher.input.feed_pb'] + full['rougher.input.feed_sol'] + full['rougher.input.feed_au'] + full['rougher.output.concentrate_ag'] + full['rougher.output.concentrate_pb'] + full['rougher.output.concentrate_sol'] + full['rougher.output.concentrate_au'] + full['primary_cleaner.output.concentrate_ag'] + full['primary_cleaner.output.concentrate_pb'] + full['primary_cleaner.output.concentrate_sol'] + full['primary_cleaner.output.concentrate_au'] + full['final.output.concentrate_ag'] + full['final.output.concentrate_pb'] + full['final.output.concentrate_sol'] + full['final.output.concentrate_au'], bins=50, range=(0, full[['rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_au', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol', 'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol', 'final.output.concentrate_au']].max().sum()), alpha=0.5)
plt.xlabel('Суммарная концентрация')
plt.ylabel('Количество наблюдений')
plt.title('Гистограмма суммарной концентрации после удаления выбросов (для данных full)')
plt.show()

# Построение гистограммы для суммарной концентрации в данных train
plt.hist(train['rougher.input.feed_ag'] + train['rougher.input.feed_pb'] + train['rougher.input.feed_sol'] + train['rougher.input.feed_au'] + train['rougher.output.concentrate_ag'] + train['rougher.output.concentrate_pb'] + train['rougher.output.concentrate_sol'] + train['rougher.output.concentrate_au'] + train['primary_cleaner.output.concentrate_ag'] + train['primary_cleaner.output.concentrate_pb'] + train['primary_cleaner.output.concentrate_sol'] + train['primary_cleaner.output.concentrate_au'] + train['final.output.concentrate_ag'] + train['final.output.concentrate_pb'] + train['final.output.concentrate_sol'] + train['final.output.concentrate_au'], bins=50, range=(0, train[['rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_au', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol', 'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol', 'final.output.concentrate_au']].max().sum()), alpha=0.5)
plt.xlabel('Суммарная концентрация')
plt.ylabel('Количество наблюдений')
plt.title('Гистограмма суммарной концентрации после удаления выбросов (для данных train)')
plt.show()

# Построение гистограммы для суммарной концентрации в данных test
plt.hist(test['rougher.input.feed_ag'] + test['rougher.input.feed_pb'] + test['rougher.input.feed_sol'] + test['rougher.input.feed_au'], bins=50, range=(0, test[['rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol', 'rougher.input.feed_au']].max().sum()), alpha=0.5)
plt.xlabel('Суммарная концентрация')
plt.ylabel('Количество наблюдений')
plt.title('Гистограмма суммарной концентрации после удаления выбросов (для данных test)')
plt.show()

# %% [markdown]
# #### Вывод
# В процессе очистки, концентрация золота увеличивается, что указывает на эффективность процесса обогащения. Концентрация других металлов может иметь различные изменения на разных этапах, что может требовать дополнительных мер по оптимизации.
#
# Размеры гранул сырья на обучающей и тестовой выборках схожи, что позволяет использовать обученную модель на тестовых данных с достаточной точностью. Так же удалил выбросы в районе нуля
#
# Суммарная концентрация всех веществ на разных стадиях процесса обогащения снижается в начальных этапах, но затем начинает возрастать ближе к финальной стадии. Это может быть обусловлено эффективностью процесса удаления примесей и отходов, а также концентрацией целевых металлов.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'>Отлично! Убрали записи с ошибками измерений.</font>

# %% [markdown]
# ## Модель

# %% [markdown]
# #### 3.1. Напишите функцию для вычисления итоговой sMAPE.

# %%
#создаю функцию для вычисления sMAPE:
def sMAPE_calc(y_target, y_predict):
    smape = np.mean(abs(y_target - y_predict) / ((abs(y_target) + abs(y_predict)) / 2)) * 100
    return smape

# %%
#создаю функцию для вычисления финального sMAPE:
def final_sMAPE_calc(smape_rougher, smape_final):
    return (0.25*smape_rougher + 0.75*smape_final)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> `sMAPE_calc` и `final_sMAPE_calc` расчитаны верно.</font>

# %% [markdown]
# #### 3.2. Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %%
#разделяю обучающую выборку на признаки:
features_train = np.array(train.drop(['rougher.output.recovery', 'final.output.recovery',
                                     'rougher.output.concentrate_au', 'primary_cleaner.output.tail_pb',
                                      'final.output.concentrate_au', 'primary_cleaner.output.concentrate_pb',
                                      'final.output.tail_sol',
                                      'rougher.calculation.floatbank10_sulfate_to_au_feed',
                                      'rougher.output.tail_sol', 'final.output.tail_au',
                                      'primary_cleaner.output.concentrate_ag',
                                      'rougher.calculation.floatbank11_sulfate_to_au_feed',
                                      'rougher.output.tail_ag', 'rougher.output.tail_pb',
                                      'secondary_cleaner.output.tail_pb', 'final.output.tail_ag',
                                      'final.output.concentrate_sol', 'primary_cleaner.output.tail_au',
                                      'secondary_cleaner.output.tail_sol', 'secondary_cleaner.output.tail_ag',
                                      'rougher.output.tail_au', 'rougher.output.concentrate_ag',
                                      'primary_cleaner.output.concentrate_sol', 'final.output.concentrate_pb',
                                      'final.output.concentrate_ag', 'secondary_cleaner.output.tail_au',
                                      'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol',
                                      'primary_cleaner.output.tail_sol',
                                      'rougher.calculation.sulfate_to_au_concentrate',
                                      'final.output.tail_pb', 'primary_cleaner.output.concentrate_au',
                                      'primary_cleaner.output.tail_ag', 'rougher.calculation.au_pb_ratio'], 
                                     axis=1)) #кроме целевых, убираю признаки, которых нет в test:

target_train_rougher = np.array(train['rougher.output.recovery'])
target_train_final = np.array(train['final.output.recovery'])

for sample in [features_train, target_train_rougher, target_train_final]:
    print(sample.shape)
# Out:
# (13304, 52)
# (13304,)
# (13304,)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> `sum_concentrate` расчитывается из признаков не известных до начала процесса и не может быть подан в модель.</s></font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font>  изменил код выше, теперь колонка sum_concentrate не добавляется в датафрейм

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>👍</font>

# %%
#вводим метрику через make_scorer
score_smape = make_scorer(sMAPE_calc, greater_is_better = False)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️ <br>
# <font color='green'>Верно, что не забываешь указать greater_is_better=False, Это пригодится для SearchCV. SMAPE — ошибка, её минимизируем.</font>

# %% [markdown]
# Инициализируем пайплайн

# %%
model_rfr = make_pipeline(StandardScaler(), RandomForestRegressor())

model_dtr = make_pipeline(StandardScaler(), DecisionTreeRegressor())

model_lr = make_pipeline(StandardScaler(), LinearRegression())

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Круто! Pipeline позволяет избежать утечек информации через Скалер даже при кроссвалидации.</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Для каких моделей нужна Стандартизация?</font>

# %%
#задаю параметры для моделей:
parameters_rfr = {'randomforestregressor__n_estimators':[1,100],
                  'randomforestregressor__max_depth':[1,10],
                  'randomforestregressor__random_state':[12345]}

parameters_dtr = {'decisiontreeregressor__max_depth':[1,10]}

parameters_lr = {'linearregression__normalize':[False]}

# %%
#поиск оптимальных параметров
grid_rougher_rfr = GridSearchCV(model_rfr, param_grid=parameters_rfr, cv=5, scoring=score_smape)
grid_final_rfr = GridSearchCV(model_rfr, param_grid=parameters_rfr, cv=5, scoring=score_smape)

grid_rougher_dtr = GridSearchCV(model_dtr, param_grid=parameters_dtr, cv=5, scoring=score_smape)
grid_final_dtr = GridSearchCV(model_dtr, param_grid=parameters_dtr, cv=5, scoring=score_smape)

grid_rougher_lr = GridSearchCV(model_lr, param_grid=parameters_lr, scoring=score_smape)
grid_final_lr = GridSearchCV(model_lr, param_grid=parameters_lr, scoring=score_smape)

# %%
#обучаю модели:
grid_rougher_rfr.fit(features_train, target_train_rougher)
grid_final_rfr.fit(features_train, target_train_final)

grid_rougher_dtr.fit(features_train, target_train_rougher)
grid_final_dtr.fit(features_train, target_train_final)

grid_rougher_lr.fit(features_train, target_train_rougher)
grid_final_lr.fit(features_train, target_train_final)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('linearregression',
#                                         LinearRegression(copy_X=True,
#                                                          fit_intercept=True,
#                                                          n_jobs=None,
#                                                          normalize=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'linearregression__normalize': [False]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
# ...

# %%
#определяю лучшую из моделей для 2 целевых признаков: 
best_score_rougher_rfr = grid_rougher_rfr.best_score_
best_score_final_rfr = grid_final_rfr.best_score_

best_score_rougher_dtr = grid_rougher_dtr.best_score_
best_score_final_dtr = grid_final_dtr.best_score_

best_score_rougher_lr = grid_rougher_lr.best_score_
best_score_final_lr = grid_final_lr.best_score_

print('по модели RandomForestRegressor лучший результат rougher =', best_score_rougher_rfr)
print('по модели DecisionTreeRegressor лучший результат rougher =', best_score_rougher_dtr)
print('по модели LinearRegression лучший результат rougher =', best_score_rougher_lr)
print()
print('по модели RandomForestRegressor лучший результат final =', best_score_final_rfr)
print('по модели DecisionTreeRegressor лучший результат final =', best_score_final_dtr)
print('по модели LinearRegression лучший результат final =', best_score_final_lr)
# Out:
# по модели RandomForestRegressor лучший результат rougher = -6.808701607411041
# по модели DecisionTreeRegressor лучший результат rougher = -7.160965334754474
# по модели LinearRegression лучший результат rougher = -7.005146464308487
#
# по модели RandomForestRegressor лучший результат final = -8.74547252381542
# по модели DecisionTreeRegressor лучший результат final = -8.80472729912597
# по модели LinearRegression лучший результат final = -9.285261832443023

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'>Подбор гиперпараметров проведён верно. Использована целевая метрика, направление отбора верное ).</font>

# %%
#вычисляю final sMAPE для каждой модели:
final_smape_rfr = final_sMAPE_calc(best_score_rougher_rfr, best_score_final_rfr)
print('по модели RandomForestRegressor итоговое sMAPE =', final_smape_rfr)

final_smape_dtr = final_sMAPE_calc(best_score_rougher_dtr, best_score_final_dtr)
print('по модели DecisionTreeRegressor итоговое sMAPE =', final_smape_dtr)

final_smape_lr = final_sMAPE_calc(best_score_rougher_lr, best_score_final_lr)
print('по модели LinearRegression итоговое sMAPE =', final_smape_lr)
# Out:
# по модели RandomForestRegressor итоговое sMAPE = -8.261279794714325
# по модели DecisionTreeRegressor итоговое sMAPE = -8.393786808033095
# по модели LinearRegression итоговое sMAPE = -8.715232990409389

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>👍</font>

# %%
#на тестовой выборке вычисляю final sMAPE по RandomForestRegressor:
features_test = np.array(test.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1))
target_test_rouger = np.array(test['rougher.output.recovery'])
target_test_final = np.array(test['final.output.recovery'])

test_rogher = grid_rougher_rfr.predict(features_test) 
test_final = grid_final_rfr.predict(features_test)

rouger_smape_test = sMAPE_calc(target_test_rouger, test_rogher)
final_smape_test = sMAPE_calc(target_test_final, test_final)

final_smape = final_sMAPE_calc(rouger_smape_test, final_smape_test)
print('Симметричная средняя абсолютная процентная ошибка на тестовой выборке =', round(final_smape,3))
# Out:
# Симметричная средняя абсолютная процентная ошибка на тестовой выборке = 7.359

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Тестирование проведено верно.</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> Нужно сравнить с константной моделью, например с `DummyRegressor`, из одного значения метрики не ясно насколько адекватно предсказание моделей. )</s></font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font>  добавил главу с проверкой на вменяемость, сравнил с модель дамми

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> Классно, что сравниваешь с константной моделью!</font>

# %% [markdown]
# ##### Вывод:
# Мы обучили три модели - случайный лес, дерево решений и линейную регрессию на тренировочной выборке с использованием кросс-валидации. Случайный лес показал лучшие метрики качества, поэтому вы протестировали его на тестовой выборке. Симметричная средняя абсолютная процентная ошибка (SMAPE) на тестовой выборке составила 7.359 Это показатель, который измеряет точность прогнозов модели и означает, что в среднем модель ошибается на 7.359% при предсказании целевой переменной.

# %% [markdown]
# # 4. Проверка модели на вменяемость

# %%
dummy_model = DummyRegressor(strategy='mean', constant=0)
dummy_model.fit(features_train, target_train_final)

dummy_predict = dummy_model.predict(features_test) 
dummy_smape = sMAPE_calc(target_test_final, dummy_predict)

print('Симметричная средняя абсолютная процентная ошибка для константной модели на тестовой выборке =', round(dummy_smape, 3))
# Out:
# Симметричная средняя абсолютная процентная ошибка для константной модели на тестовой выборке = 9.216

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ⚠️\
# <font color='darkorange'>Стоит сравнить по Итоговой sMAPE.</font>

# %% [markdown]
# ##### Вывод
# Модель RandomForestRegressor показала более высокие значения метрик по сравнению с константной моделью, что говорит о ее лучшей производительности и точности предсказаний

# %% [markdown]
# ## Общий вывод
# Мы провели анализ данных, связанных с процессом обогащения руды. В процессе исследования мы изучили характеристики сырья, этапы технологического процесса, а также целевые показатели эффективности обогащения. Были проанализированы изменения концентраций металлов на разных стадиях процесса и размеры гранул сырья.
#
# Мы выявили некоторые особенности данных, такие как пропуски и выбросы. Пропущенные значения были заполнены и выбросы были удалены, чтобы обеспечить корректность анализа и построения модели.
#
# Далее мы построили модель для предсказания эффективности обогащения на этапе флотации. Были обучены три модели - случайный лес, дерево решений и линейная регрессия - с использованием кросс-валидации. По результатам оценки метрик качества моделей, случайный лес показал наилучшие результаты.
#
# Проверка модели на тестовой выборке подтвердила ее хорошую предсказательную способность. Симметричная средняя абсолютная процентная ошибка (SMAPE) составила 7.331, что означает, что модель в среднем ошибается на 7.331% при предсказании целевого показателя.
#
# Сравнивая результаты метрик константной модели с моделью RandomForestRegressor, мы видим, что последняя показывает более высокие значения метрик. Это говорит о том, что RandomForestRegressor демонстрирует более точные предсказания и проходит проверку на вменяемость.
#
# Таким образом, мы разработали модель, которая может помочь в оценке эффективности обогащения руды на основе доступных характеристик. Это может быть полезным инструментом для оптимизации процесса обогащения и улучшения его эффективности.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Очень приятно видеть вывод в конце проекта!\
# Приведены ответы на главные вопросы проекта.</font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера</b></font>\
# <font color='green'>Хороший проект получился!
# Большое спасибо за проделанную работу. Видно, что приложено много усилий.
# Выводы и рассуждения получились содержательными, их было интересно читать.
# </font>
#
# <font color='blue'>Что нужно исправить:</font>
# <ul><font color='red'>Какие особенности имеют распределения концентраций металлов? Опишите выводы.</font></ul>
# <ul><font color='red'>Нормализуй гистограммы для сравнения расперделений размеров гранул.</font></ul>
# <ul><font color='red'>Не фильтруй тестовые данные. Работать модели предстоит с каждым входящим наблюдением.</font></ul>
# <ul><font color='red'>Для обучения моделей используй только признаки доступные до начала технологического процесса.</font></ul>
# <ul><font color='red'>Добавь тест константной модели для оценки адекватности работы моделей.</font></ul>
#
# <font color='blue'>Что можно сделать лучше:</font>
# <font color='darkorange'>В работе я оставил несколько советов. Буду рад, если ты учтешь их.</font></ul>
#
# <font color='blue'><b>Жду новую версию проекта :)</b></font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера 2</b></font>\
# <font color='green'>Проект принят! \
# Все этапы пройдены. Все критичные рекомендации учтены.\
# Надеюсь, тебе понравился процесс выполнения и результат.</font> \
# <font color='blue'><b>Спасибо, удачи в освоении профессии!</b></font>
